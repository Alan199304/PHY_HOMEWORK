# %%
import pandas as pd
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set the plots to display in the Jupyter notebook
# %matplotlib inline

# change plotting colors per client request
plt.style.use('ggplot')

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
print(f'I am using {pd.__name__} \
Version: {pd.__version__}.\n\
It is installed at: {pd.__path__}')
# Out:
# I am using pandas Version: 1.4.2.
# It is installed at: ['C:\\Users\\xiaoz\\anaconda3\\lib\\site-packages\\pandas']

# %%
# Read the data via Jupiter Notebook
QS = pd.read_csv('C:\\Users\\xiaoz\\OneDrive\\Desktop\\2023_QS_World_University_Rankings.csv')

# %%
# Top University Ranking in QS World university Ranking 2023
QS.head()
# Out:
#    Rank                                   institution location code  \
# 0     1  Massachusetts Institute of Technology (MIT)             US
# 1     2                       University of Cambridge            UK
# 2     3                           Stanford University            US
# 3     4                          University of Oxford            UK
# 4     5                            Harvard University            US
#
#          location  ar score ar rank  er score er rank  fsr score fsr rank  \
# 0   United States     100.0       5     100.0       4      100.0       14
# 1  United Kingdom     100.0       2     100.0       2      100.0       11
# 2   United States     100.0       4     100.0       5      100.0        6
# 3  United Kingdom     100.0       3     100.0       3      100.0        8
# 4   United States     100.0       1     100.0       1       99.4       35
#
#    ...  cpf rank ifr score  ifr rank isr score  isr rank irn score  irn rank  \
# ...

# %%
# show the type of QS World university Ranking dataset
type(QS.shape)
# Out:
# tuple

# %%
# How many column x row
QS.shape
# Out:
# (1422, 21)

# %%
# Showing the Total Number of university that recorded in this dataset
# Number of column
QS.shape[0]
# Out:
# 1422

# %%
# Make The 'Rank' as primary key
QS1 = QS.set_index('Rank')

# %%
QS1.head()
# Out:
#                                        institution location code  \
# Rank
# 1     Massachusetts Institute of Technology (MIT)             US
# 2                          University of Cambridge            UK
# 3                              Stanford University            US
# 4                             University of Oxford            UK
# 5                               Harvard University            US
#
#             location  ar score ar rank  er score er rank  fsr score fsr rank  \
# Rank
# 1      United States     100.0       5     100.0       4      100.0       14
# 2     United Kingdom     100.0       2     100.0       2      100.0       11
# 3      United States     100.0       4     100.0       5      100.0        6
# 4     United Kingdom     100.0       3     100.0       3      100.0        8
# 5      United States     100.0       1     100.0       1       99.4       35
#
#       cpf score cpf rank  ifr score ifr rank  isr score isr rank  irn score  \
# Rank
# ...

# %%
# Check is there have any missing data in beginning
# Seem the data did not missing
QS1.notnull().head()
# Out:
#       institution  location code  location  ar score  ar rank  er score  \
# Rank
# 1            True           True      True      True     True      True
# 2            True           True      True      True     True      True
# 3            True           True      True      True     True      True
# 4            True           True      True      True     True      True
# 5            True           True      True      True     True      True
#
#       er rank  fsr score  fsr rank  cpf score  cpf rank  ifr score  ifr rank  \
# Rank
# 1        True       True      True       True      True       True      True
# 2        True       True      True       True      True       True      True
# 3        True       True      True       True      True       True      True
# 4        True       True      True       True      True       True      True
# 5        True       True      True       True      True       True      True
#
# ...

# %%
# Check is there have any missing data in the end
# Seem there are some data was missing
QS1.notnull().tail()
# Out:
#       institution  location code  location  ar score  ar rank  er score  \
# Rank
# 1418         True           True      True      True     True      True
# 1419         True           True      True      True     True      True
# 1420         True           True      True      True     True      True
# 1421         True           True      True      True     True      True
# 1422         True           True      True      True     True      True
#
#       er rank  fsr score  fsr rank  cpf score  cpf rank  ifr score  ifr rank  \
# Rank
# 1418     True       True      True       True      True       True      True
# 1419     True       True      True       True      True       True      True
# 1420     True       True      True       True      True       True      True
# 1421     True       True      True       True      True      False     False
# 1422     True       True      True       True      True       True      True
#
# ...

# %%
# count how many null in the column
unknown_value = pd.DataFrame(QS1.isnull().sum(), columns=['Count of Nulls'])
unknown_value.index.name = 'Column'
unknown_value.sort_values(['Count of Nulls'], ascending=False).head(21)
# Out:
#                Count of Nulls
# Column
# ifr rank                   98
# ifr score                  98
# isr rank                   57
# isr score                  57
# irn rank                   13
# irn score                  13
# ger rank                   12
# ger score                  12
# cpf score                   5
# fsr score                   2
# er score                    1
# institution                 0
# cpf rank                    0
# location code               0
# fsr rank                    0
# er rank                     0
# ar rank                     0
# ar score                    0
# location                    0
# score scaled                0

# %%
# count the 'null' value in 'er score' from original data 
QS1['er score'].isnull().sum()
# Out:
# 1

# %%
# count of each value available in column 'er score'
QS1['er score'].value_counts(dropna=False)
# Out:
# 3.2     20
# 3.4     17
# 2.5     17
# 5.0     16
# 2.1     16
#         ..
# 45.7     1
# 62.2     1
# 76.8     1
# 33.7     1
# 17.6     1
# Name: er score, Length: 506, dtype: int64

# %%
# replace the 'null' with '0'
QS2 = QS1.fillna(value={"er score":"0"})

# %%
# check new data in 'er score' for any 'null' 
QS2['er score'].isnull().sum()
# Out:
# 0

# %%
QS1.columns
#institution = Location
#location code = Location in short form
#location = Location in Full Name
# ar score = Academic Reputation score (The University that illuminates the quality of the research, that able to impact across the world.) 
#ar rank = Academic Reputation rank
# er score = Employer Reputation score (The higher chance the Employer hire/put into consideration while employing new undergraduate students)
#er rank = Employer Reputation rank
#fsr score = Faculty Student score (more academic staff resource made available to students, the better this experience ought to be)
#fsr rank = Faculty Student rank
#cpf score = Citations per faculty score (represents the total number of citations received by all papers produced by an institution across a five-year period by the number of faculty members at that institution.)
#cpf rank = Citations per faculty rank
#ifr score = International Faculty score (the ratio of international faculty staff to overall staff.)
#ifr rank = International Faculty rank
#isr score = International Students score (the ratio of international students to overall students.)
#isr rank = International Students rank
#irn score = International Research Network score (reflects the ability of institutions to diversify the geography of their international research network by establishing sustainable research partnerships with other higher education institutions)
#irn rank = International Research Network rank
#ger score = Employment Outcome score (to reflect the ability of institutions to ensure a high level of employability for their graduates)
#ger rank = Employment Outcome rank
#score scaled = Overall
# Out:
# Index(['institution', 'location code', 'location', 'ar score', 'ar rank',
#        'er score', 'er rank', 'fsr score', 'fsr rank', 'cpf score', 'cpf rank',
#        'ifr score', 'ifr rank', 'isr score', 'isr rank', 'irn score',
#        'irn rank', 'ger score', 'ger rank', 'score scaled'],
#       dtype='object')

# %%
pd.DataFrame(QS1.dtypes,columns = ['Datatypes'])
# Out:
#               Datatypes
# institution      object
# location code    object
# location         object
# ar score        float64
# ar rank          object
# er score        float64
# er rank          object
# fsr score       float64
# fsr rank         object
# cpf score       float64
# cpf rank         object
# ifr score       float64
# ifr rank         object
# isr score       float64
# isr rank         object
# irn score       float64
# irn rank         object
# ger score       float64
# ger rank         object
# score scaled     object

# %%
list(QS1.columns)
# Out:
# ['institution',
#  'location code',
#  'location',
#  'ar score',
#  'ar rank',
#  'er score',
#  'er rank',
#  'fsr score',
#  'fsr rank',
#  'cpf score',
#  'cpf rank',
#  'ifr score',
#  'ifr rank',
#  'isr score',
#  'isr rank',
#  'irn score',
#  'irn rank',
#  'ger score',
#  'ger rank',
#  'score scaled']

# %%
# Check how many University are listed in QS ranking from their country
QS1['location'].value_counts()
# Out:
# United States       201
# United Kingdom       90
# China (Mainland)     71
# Japan                50
# Russia               48
#                    ...
# Paraguay              1
# Georgia               1
# Qatar                 1
# Kyrgyzstan            1
# Morocco               1
# Name: location, Length: 100, dtype: int64

# %%
# The Universities in these countries have been listed in the QS World Unieristy Ranking 2023
QS1['location'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Switzerland', 'Singapore',
#        'China (Mainland)', 'Hong Kong SAR', 'Japan', 'France',
#        'South Korea', 'Australia', 'Canada', 'Germany', 'Netherlands',
#        'Argentina', 'Malaysia', 'Russia', 'Belgium', 'Taiwan', 'Denmark',
#        'New Zealand', 'Sweden', 'Ireland', 'Norway', 'Mexico',
#        'Saudi Arabia', 'Finland', 'Brazil', 'Chile', 'Italy',
#        'Kazakhstan', 'Austria', 'India', 'Spain', 'United Arab Emirates',
#        'Qatar', 'Colombia', 'Israel', 'Thailand', 'Indonesia',
#        'South Africa', 'Lebanon', 'Brunei', 'Portugal', 'Poland',
#        'Belarus', 'Czech Republic', 'Estonia', 'Macau SAR', 'Pakistan',
#        'Peru', 'Iran, Islamic Republic of', 'Oman', 'Lithuania',
#        'Philippines', 'Egypt', 'Greece', 'Uruguay', 'Cuba', 'Cyprus',
#        'Turkey', 'Costa Rica', 'Ukraine', 'Hungary', 'Bahrain',
#        'Bulgaria', 'Jordan', 'Georgia', 'Slovenia', 'Slovakia', 'Kuwait',
# ...

# %%
# In these university, how many country has been listed in the QS World Unieristy Ranking 2023?
QS1['location'].nunique()
# Out:
# 100

# %%
# The total number of university that listed in country
QS1['location'].value_counts()
# Out:
# United States       201
# United Kingdom       90
# China (Mainland)     71
# Japan                50
# Russia               48
#                    ...
# Paraguay              1
# Georgia               1
# Qatar                 1
# Kyrgyzstan            1
# Morocco               1
# Name: location, Length: 100, dtype: int64

# %%
# All the QS World university Ranking 2023 in Bar chart
plt.figure(figsize=(25,50))
QS1['location'].value_counts().plot(kind='barh').ascending= True
plt.xlabel('Location of Institution')
plt.ylabel('Number of Ranking')
plt.title('QS World university Ranking 2023')
# Out:
# Text(0.5, 1.0, 'QS World university Ranking 2023')

# %%
# Top 100 Listed QS World university Ranking 2023
QS1.head(100)
# Out:
#                                            institution location code  \
# Rank
# 1         Massachusetts Institute of Technology (MIT)             US
# 2                              University of Cambridge            UK
# 3                                  Stanford University            US
# 4                                 University of Oxford            UK
# 5                                   Harvard University            US
# ...                                                ...           ...
# 96                         The University of Sheffield            UK
# 97                            University of St Andrews            UK
# 98    Trinity College Dublin, The University of Dublin            IE
# 99                       Sungkyunkwan University(SKKU)            KR
# 100                                    Rice University            US
#
#             location  ar score ar rank  er score er rank  fsr score fsr rank  \
# Rank
# ...

# %%
QStop100 = QS1.head(100)

# %%
# Double Check
QStop100
# Out:
#                                            institution location code  \
# Rank
# 1         Massachusetts Institute of Technology (MIT)             US
# 2                              University of Cambridge            UK
# 3                                  Stanford University            US
# 4                                 University of Oxford            UK
# 5                                   Harvard University            US
# ...                                                ...           ...
# 96                         The University of Sheffield            UK
# 97                            University of St Andrews            UK
# 98    Trinity College Dublin, The University of Dublin            IE
# 99                       Sungkyunkwan University(SKKU)            KR
# 100                                    Rice University            US
#
#             location  ar score ar rank  er score er rank  fsr score fsr rank  \
# Rank
# ...

# %%
# total number of institution on each country Listed in top 100 QS World university Ranking 2023
QStop100['location'].value_counts()
# Out:
# United States       27
# United Kingdom      17
# Australia            7
# China (Mainland)     6
# South Korea          6
# Hong Kong SAR        5
# Japan                5
# France               4
# Canada               3
# Germany              3
# Switzerland          3
# Singapore            2
# Netherlands          2
# Sweden               2
# Argentina            1
# Malaysia             1
# Russia               1
# Belgium              1
# Taiwan               1
# Denmark              1
# New Zealand          1
# Ireland              1
# Name: location, dtype: int64

# %%
# Top 100 QS World university Ranking 2023 in Bar chart

QStop100['location'].value_counts().head(100).plot(kind='bar')
plt.xlabel('Location of Institution')
plt.ylabel('Number of Ranking')
plt.title('QS World university Ranking 2023')
# Out:
# Text(0.5, 1.0, 'QS World university Ranking 2023')

# %%
# The top 10 Malaysia University that listed in QS Ranking 2023
QS1[QS1['location'] == 'Malaysia'].head(10)
# Out:
#                                institution location code  location  ar score  \
# Rank
# 70                  Universiti Malaya (UM)            MY  Malaysia      79.6
# 123        Universiti Putra Malaysia (UPM)            MY  Malaysia      56.8
# 130   Universiti Kebangsaan Malaysia (UKM)            MY  Malaysia      57.9
# 144        Universiti Sains Malaysia (USM)            MY  Malaysia      59.7
# 203         Universiti Teknologi Malaysia             MY  Malaysia      44.5
# 285                    Taylor's University            MY  Malaysia      21.5
# 286                        UCSI University            MY  Malaysia      20.5
# 361    Universiti Teknologi PETRONAS (UTP)            MY  Malaysia      16.4
# 485        Universiti Utara Malaysia (UUM)            MY  Malaysia      19.4
# 620      Management and Science University            MY  Malaysia      10.7
#
#      ar rank  er score er rank  fsr score fsr rank  cpf score cpf rank  \
# Rank
# ...

# %%
# How many University in Malaysia has been listed in QS Ranking 2023
QSM = QS1[QS1['location'] == 'Malaysia']
QSM.shape[0]
# Out:
# 24

# %%
QSM.groupby('institution')['er score','ar score'].agg(['count','mean','min','max'])
# Out:
# C:\Users\xiaoz\AppData\Local\Temp\ipykernel_22668\400971578.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   QSM.groupby('institution')['er score','ar score'].agg(['count','mean','min','max'])
#                                                    er score                    \
#                                                       count  mean   min   max
# institution
# International Islamic University Malaysia (IIUM)          1  16.7  16.7  16.7
# Management and Science University                         1  14.7  14.7  14.7
# Multimedia University (MMU)                               1  17.4  17.4  17.4
# Sunway University                                         1  36.8  36.8  36.8
# Taylor's University                                       1  80.0  80.0  80.0
# UCSI University                                           1  54.9  54.9  54.9
# ...

# %%
# highest score in institution in Malaysia
print(QSM['ar score'].max())
print(QSM['er score'].max())
# Out:
# 79.6
# 94.9

# %%
# highest ar score and er score in institution Malaysia
QSM[(QSM['ar score']==QSM['ar score'].max())]
QSM[(QSM['er score']==QSM['er score'].max())]
# Out:
#                  institution location code  location  ar score ar rank  \
# Rank
# 70    Universiti Malaya (UM)            MY  Malaysia      79.6      70
#
#       er score er rank  fsr score fsr rank  cpf score cpf rank  ifr score  \
# Rank
# 70        94.9      35       67.8      200       39.4      355       43.6
#
#      ifr rank  isr score isr rank  irn score irn rank  ger score ger rank  \
# Rank
# 70        388       53.0      272       91.8      126       41.9      310
#
#      score scaled
# Rank
# 70           67.9

# %%
# ar score = Academic Reputation score (The University that illuminates the quality of the research, that able to impact across the world.) 
# best er score 
# Employer Reputation score(The higher chance the Employer hire/put into consideration while employing new undergraduate students)
QSM[['institution','er score','ar score']].groupby(['institution']).max().sort_values('er score',ascending = False)
# Out:
#                                                     er score  ar score
# institution
# Universiti Malaya (UM)                                  94.9      79.6
# Taylor's University                                     80.0      21.5
# Universiti Sains Malaysia (USM)                         66.6      59.7
# Universiti Kebangsaan Malaysia (UKM)                    62.0      57.9
# Universiti Putra Malaysia (UPM)                         59.2      56.8
# Universiti Teknologi Malaysia                           55.9      44.5
# UCSI University                                         54.9      20.5
# Universiti Teknologi MARA - UiTM                        47.4      26.8
# Sunway University                                       36.8       8.4
# Universiti Tunku Abdul Rahman (UTAR)                    32.1      11.4
# Universiti Teknologi PETRONAS (UTP)                     29.8      16.4
# Universiti Utara Malaysia (UUM)                         23.3      19.4
# ...

# %%
# plot 'institution' over 'er score'
QSM[['institution','er score']].groupby(['institution']).max().sort_values('er score',ascending = True).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='institution'>

# %%
# plot 'institution' over 'er score' and 'ar score'
QSM[['ar score','er score','institution']].groupby(by=['institution']).max().sort_values('er score',ascending = True).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='institution'>

# %%
QS1[QS1['location'] == 'United States'].head(10)
# Out:
#                                        institution location code  \
# Rank
# 1     Massachusetts Institute of Technology (MIT)             US
# 3                              Stanford University            US
# 5                               Harvard University            US
# 6     California Institute of Technology (Caltech)            US
# 10                           University of Chicago            US
# 13                      University of Pennsylvania            US
# 17                            Princeton University            US
# 18                                 Yale University            US
# 20                              Cornell University            US
# 22                             Columbia University            US
#
#            location  ar score ar rank  er score er rank  fsr score fsr rank  \
# Rank
# 1     United States     100.0       5     100.0       4      100.0       14
# 3     United States     100.0       4     100.0       5      100.0        6
# ...

# %%
QS1['location'].unique()
# Out:
# array(['United States', 'United Kingdom', 'Switzerland', 'Singapore',
#        'China (Mainland)', 'Hong Kong SAR', 'Japan', 'France',
#        'South Korea', 'Australia', 'Canada', 'Germany', 'Netherlands',
#        'Argentina', 'Malaysia', 'Russia', 'Belgium', 'Taiwan', 'Denmark',
#        'New Zealand', 'Sweden', 'Ireland', 'Norway', 'Mexico',
#        'Saudi Arabia', 'Finland', 'Brazil', 'Chile', 'Italy',
#        'Kazakhstan', 'Austria', 'India', 'Spain', 'United Arab Emirates',
#        'Qatar', 'Colombia', 'Israel', 'Thailand', 'Indonesia',
#        'South Africa', 'Lebanon', 'Brunei', 'Portugal', 'Poland',
#        'Belarus', 'Czech Republic', 'Estonia', 'Macau SAR', 'Pakistan',
#        'Peru', 'Iran, Islamic Republic of', 'Oman', 'Lithuania',
#        'Philippines', 'Egypt', 'Greece', 'Uruguay', 'Cuba', 'Cyprus',
#        'Turkey', 'Costa Rica', 'Ukraine', 'Hungary', 'Bahrain',
#        'Bulgaria', 'Jordan', 'Georgia', 'Slovenia', 'Slovakia', 'Kuwait',
# ...

# %%
QS1['location code'].unique()
# Out:
# array(['US', 'UK', 'CH', 'SG', 'CN', 'HK', 'JP', 'FR', 'KR', 'AU', 'CA',
#        'DE', 'NL', 'AR', 'MY', 'RU', 'BE', 'TW', 'DK', 'NZ', 'SE', 'IE',
#        'NO', 'MX', 'SA', 'FI', 'BR', 'CL', 'IT', 'KZ', 'AT', 'IN', 'ES',
#        'AE', 'SK', 'QA', 'CO', 'IL', 'TH', 'ID', 'ZA', 'LB', 'BN', 'PT',
#        'PL', 'BY', 'CZ', 'EE', 'MO', 'PK', 'PE', 'IR', 'OM', 'LT', 'PH',
#        'EG', 'GR', 'UY', 'CU', 'CY', 'TR', 'CR', 'UA', 'HU', 'BH', 'BG',
#        'JO', 'GE', 'SI', 'KW', 'VE', 'EC', 'LV', 'TN', 'BD', 'VN', 'DO',
#        'KG', 'AM', 'IQ', 'MT', 'HR', 'PS', 'AZ', 'RO', 'PY', 'PA', 'RS',
#        'KE', 'LK', 'UG', 'PR', 'GT', 'BO', 'GH', 'SD', 'BA', 'SY', 'HN',
#        'MA'], dtype=object)

# %%
def location_match(location1): 
    
    all_location = {'United States':'US', 
                      'United Kingdom':'UK', 
                      'Switzerland':'CH', 
                      'Singapore':'SG',
       'China (Mainland)':'CN', 
                      'Hong Kong SAR':'HK', 
                      'Japan':'JP', 
                      'France':'FR'}
    
    try:
        return all_location[location1]
    except:
        return 'Not in the location list'

# %%
location_match('United States')
# Out:
# 'US'

# %%
QS1['location1'].apply(location_match) ==
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
x = input()
location_match('x')
# Out:
# United States
# 'Not in the location list'
